# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Dataset

# %%
df_dir = 'C:/Users/huang/Downloads/'
df = pd.read_csv(df_dir + 'Iowa_Liquor_Sales.csv')
# Out:
# C:\Users\huang\AppData\Local\Temp\ipykernel_23764\3096593678.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(df_dir + 'Iowa_Liquor_Sales.csv')

# %% [markdown]
# # Explore Dataset

# %%
df.head()
# Out:
#   Invoice/Item Number        Date  Store Number  \
# 0        S29198800001  11/20/2015          2191
# 1        S29195400002  11/21/2015          2205
# 2        S29050300001  11/16/2015          3549
# 3        S28867700001  11/04/2015          2513
# 4        S29050800001  11/17/2015          3942
#
#                          Store Name              Address          City  \
# 0                    Keokuk Spirits            1013 MAIN        KEOKUK
# 1            Ding's Honk And Holler     900 E WASHINGTON      CLARINDA
# 2              Quicker Liquor Store         1414 48TH ST  FORT MADISON
# 3  Hy-Vee Food Store #2 / Iowa City       812  S 1ST AVE     IOWA CITY
# 4                  Twin Town Liquor  104 HIGHWAY 30 WEST        TOLEDO
#
#   Zip Code                                     Store Location  County Number  \
# 0    52632    1013 MAIN\nKEOKUK 52632\n(40.39978, -91.387531)           56.0
# 1    51632  900 E WASHINGTON\nCLARINDA 51632\n(40.739238, ...           73.0
# ...

# %%
print(f'There are {df.shape[1]} features in the dataset.')
print(f'There are {df.shape[0]:,} records in the dataset.')
# Out:
# There are 24 features in the dataset.
# There are 12,591,077 records in the dataset.

# %%
num_of_missing_values = df.isnull().sum()         # Count missing values in each feature
percentage_missing = ((num_of_missing_values / df.shape[0]) * 100).apply("{:.2f}%".format)        # Calculate the percentage of missing values

data = {
    'Data Type' : df.dtypes,          # Print data type of each feature
    'Number of Unique Values': df.nunique(),         # Count unique values in each feature
    'Number of Missing Values': num_of_missing_values,
    'Percentage of Missing Values': percentage_missing
}

pd.DataFrame(data)
# Out:
#                       Data Type  Number of Unique Values  \
# Invoice/Item Number      object                 12591077
# Date                     object                     1379
# Store Number              int64                     1884
# Store Name               object                     1952
# Address                  object                     3154
# City                     object                      793
# Zip Code                 object                      871
# Store Location           object                     4477
# County Number           float64                       99
# County                   object                      200
# Category                float64                      107
# Category Name            object                      130
# Vendor Number           float64                      271
# Vendor Name              object                      393
# Item Number               int64                     7395
# ...

# %%
print('There are some missing values in the columns like "Address", "City", "Country" and so on, \nhowever, we notice that there are no any missing values in the "Store Number" and "Store Name", \nwe may use these columns to help us predict the missing values.')
# Out:
# There are some missing values in the columns like "Address", "City", "Country" and so on,
# however, we notice that there are no any missing values in the "Store Number" and "Store Name",
# we may use these columns to help us predict the missing values.

# %%
print(f'The dataset contains records from {df.Date.min()} to {df.Date.max()}.')
# Out:
# The dataset contains records from 01/02/2013 to 12/31/2015.
